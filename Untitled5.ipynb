# %%
import tkinter as tk
from tkinter import ttk
from tkinter import scrolledtext
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
import pandas as pd

# Load the data from CSV file
data = pd.read_csv('res_review.csv')

# Initialize TF-IDF vectorizer
vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')
X = vectorizer.fit_transform(data[' Review'])  # Use ' Review' column for text vectorization
y = data['Liked']

# Train the SVM classifier
svm_classifier = SVC(kernel='linear')
svm_classifier.fit(X, y)

def predict_sentiment():
    input_text = input_entry.get()
    if not input_text:
        sentiment_display.configure(text="Please enter a review.")
        return

    input_vectorized = vectorizer.transform([input_text])
    predicted_sentiment = svm_classifier.predict(input_vectorized)
    sentiment_mapping = {0: 'Negative', 1: 'Positive'}  # Map integer predictions to sentiment labels

    if predicted_sentiment[0] in sentiment_mapping:
        predicted_sentiment_human_readable = sentiment_mapping[predicted_sentiment[0]]
        sentiment_display.configure(text=f"Predicted Sentiment: {predicted_sentiment_human_readable}")

        # Update recommendation based on sentiment
        if predicted_sentiment[0] == 0:  # Negative sentiment
            recommendation_label.configure(text="Recommendation: It's not recommended to visit the restaurant.")
        else:
            recommendation_label.configure(text="Recommendation: You can consider visiting the restaurant.")
    else:
        sentiment_display.configure(text="Error: Unexpected sentiment prediction.")
        recommendation_label.configure(text="")

def filter_reviews(sentiment):
    filtered_data = data[data['Liked'] == sentiment]
    positive_count = len(filtered_data[filtered_data['Liked'] == 1])
    negative_count = len(filtered_data[filtered_data['Liked'] == 0])
    sentiment_stats_label.configure(text=f"Positive Reviews: {positive_count}, Negative Reviews: {negative_count}")

# Create a Tkinter window
root = tk.Tk()
root.title("Restaurant Review Sentiment Analysis")

# Create GUI elements
input_label = ttk.Label(root, text="Enter a Review:")
input_label.pack(pady=10)

input_entry = ttk.Entry(root, width=80)
input_entry.pack()

predict_button = ttk.Button(root, text="Predict", command=predict_sentiment)
predict_button.pack(pady=10)

sentiment_display = ttk.Label(root, text="", wraplength=600, justify='center', relief='solid', borderwidth=1, padding=10)
sentiment_display.pack(pady=20)

recommendation_label = ttk.Label(root, text="", font=("Arial", 12, "bold"))
recommendation_label.pack(pady=10)

sentiment_stats_label = ttk.Label(root, text="Sentiment Stats:")
sentiment_stats_label.pack(pady=10)

positive_button = ttk.Button(root, text="Positive Reviews", command=lambda: filter_reviews(1))
positive_button.pack(pady=5)

negative_button = ttk.Button(root, text="Negative Reviews", command=lambda: filter_reviews(0))
negative_button.pack(pady=5)

# Start the Tkinter event loop
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
from tkinter import scrolledtext
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
import pandas as pd

# Load the data from CSV file
data = pd.read_csv('res_review.csv')

# %%
# Initialize TF-IDF vectorizer
vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')
X = vectorizer.fit_transform(data[' Review'])  # Use ' Review' column for text vectorization
y = data['Liked']

# %%
svm_classifier = SVC(kernel='linear')
svm_classifier.fit(X, y)
# Out:
# SVC(kernel='linear')

# %%
def predict_sentiment():
    input_text = input_entry.get()
    if not input_text:
        sentiment_display.configure(text="Please enter a review.")
        return

    input_vectorized = vectorizer.transform([input_text])
    predicted_sentiment = svm_classifier.predict(input_vectorized)
    sentiment_mapping = {0: 'Negative', 1: 'Positive'}  # Map integer predictions to sentiment labels

    if predicted_sentiment[0] in sentiment_mapping:
        predicted_sentiment_human_readable = sentiment_mapping[predicted_sentiment[0]]
        sentiment_display.configure(text=f"Predicted Sentiment: {predicted_sentiment_human_readable}")

        # Update recommendation based on sentiment
        if predicted_sentiment[0] == 0:  # Negative sentiment
            recommendation_label.configure(text="Recommendation: It's not recommended to visit the restaurant.")
        else:
            recommendation_label.configure(text="Recommendation: You can consider visiting the restaurant.")
    else:
        sentiment_display.configure(text="Error: Unexpected sentiment prediction.")
        recommendation_label.configure(text="")

def filter_reviews(sentiment):
    filtered_data = data[data['Liked'] == sentiment]
    positive_count = len(filtered_data[filtered_data['Liked'] == 1])
    negative_count = len(filtered_data[filtered_data['Liked'] == 0])
    sentiment_stats_label.configure(text=f"Positive Reviews: {positive_count}, Negative Reviews: {negative_count}")

# %%
# Create a Tkinter window
root = tk.Tk()
root.title("Restaurant Review Sentiment Analysis")

# Create GUI elements
input_label = ttk.Label(root, text="Enter a Review:")
input_label.pack(pady=10)

input_entry = ttk.Entry(root, width=80)
input_entry.pack()

predict_button = ttk.Button(root, text="Predict", command=predict_sentiment)
predict_button.pack(pady=10)

sentiment_display = ttk.Label(root, text="", wraplength=600, justify='center', relief='solid', borderwidth=1, padding=10)
sentiment_display.pack(pady=20)

recommendation_label = ttk.Label(root, text="", font=("Arial", 12, "bold"))
recommendation_label.pack(pady=10)

# %%
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from CSV file
data = pd.read_csv('res_review.csv')

# Initialize TF-IDF vectorizer
vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')
X = vectorizer.fit_transform(data[' Review'])  # Use ' Review' column for text vectorization
y = data['Liked']

# Train the SVM classifier
svm_classifier = SVC(kernel='linear')
svm_classifier.fit(X, y)

def predict_sentiment():
    input_text = input_entry.get()
    if not input_text:
        sentiment_display.configure(text="Please enter a review.")
        return

    input_vectorized = vectorizer.transform([input_text])
    predicted_sentiment = svm_classifier.predict(input_vectorized)
    sentiment_mapping = {0: 'Negative', 1: 'Positive'}  # Map integer predictions to sentiment labels

    if predicted_sentiment[0] in sentiment_mapping:
        predicted_sentiment_human_readable = sentiment_mapping[predicted_sentiment[0]]
        sentiment_display.configure(text=f"Predicted Sentiment: {predicted_sentiment_human_readable}")

        # Update recommendation based on sentiment
        if predicted_sentiment[0] == 0:  # Negative sentiment
            recommendation_label.configure(text="Recommendation: It's not recommended to visit the restaurant.")
        else:
            recommendation_label.configure(text="Recommendation: You can consider visiting the restaurant.")

        # Display detailed review and sentiment
        review_text = data[' Review'].iloc[0]  # Assuming we use the first review for display
        detailed_review_display.configure(text=f"Review: {review_text}\nPredicted Sentiment: {predicted_sentiment_human_readable}")

        # Calculate and display overall sentiment score
        positive_count = len(data[data['Liked'] == 1])
        negative_count = len(data[data['Liked'] == 0])
        overall_sentiment_score = positive_count / (positive_count + negative_count)
        overall_sentiment_label.configure(text=f"Overall Sentiment Score: {overall_sentiment_score:.2f}")

        # Update sentiment analysis visualization
        plt.figure(figsize=(6, 4))
        plt.bar(['Positive', 'Negative'], [positive_count, negative_count], color=['green', 'red'])
        plt.xlabel('Sentiment')
        plt.ylabel('Count')
        plt.title('Sentiment Analysis')
        plt.tight_layout()
        plt.savefig('sentiment_analysis.png')

#         # Display the visualization
#         img = tk.PhotoImage(file='sentiment_analysis.png')
#         sentiment_chart_display.configure(image=img)
#         sentiment_chart_display.image = img

    else:
        sentiment_display.configure(text="Error: Unexpected sentiment prediction.")
        recommendation_label.configure(text="")
        detailed_review_display.configure(text="")
        overall_sentiment_label.configure(text="")
        sentiment_chart_display.configure(image="")

# Create a Tkinter window
root = tk.Tk()
root.title("Restaurant Review Sentiment Analysis")

# Create GUI elements
input_label = ttk.Label(root, text="Enter a Review:")
input_label.pack(pady=10)

input_entry = ttk.Entry(root, width=80)
input_entry.pack()

predict_button = ttk.Button(root, text="Predict", command=predict_sentiment)
predict_button.pack(pady=10)

sentiment_display = ttk.Label(root, text="", wraplength=600, justify='center', relief='solid', borderwidth=1, padding=10)
sentiment_display.pack(pady=20)

recommendation_label = ttk.Label(root, text="", font=("Arial", 12, "bold"))
recommendation_label.pack(pady=10)

detailed_review_display = ttk.Label(root, text="", wraplength=600, justify='center', relief='solid', borderwidth=1, padding=10)
detailed_review_display.pack(pady=20)

overall_sentiment_label = ttk.Label(root, text="")
overall_sentiment_label.pack(pady=10)

sentiment_chart_display = tk.Label(root)
sentiment_chart_display.pack()

# Start the Tkinter event loop
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from CSV file
data = pd.read_csv('res_review.csv')

# Initialize TF-IDF vectorizer
vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')
X = vectorizer.fit_transform(data[' Review'])  # Use ' Review' column for text vectorization
y = data['Liked']

# Train the SVM classifier
svm_classifier = SVC(kernel='linear')
svm_classifier.fit(X, y)

def predict_sentiment():
    input_text = input_entry.get()
    if not input_text:
        sentiment_display.configure(text="Please enter a review.")
        return

    input_vectorized = vectorizer.transform([input_text])
    predicted_sentiment = svm_classifier.predict(input_vectorized)
    sentiment_mapping = {0: 'Negative', 1: 'Positive'}  # Map integer predictions to sentiment labels

    if predicted_sentiment[0] in sentiment_mapping:
        predicted_sentiment_human_readable = sentiment_mapping[predicted_sentiment[0]]
        sentiment_display.configure(text=f"Predicted Sentiment: {predicted_sentiment_human_readable}")

        # Update recommendation based on sentiment of last 10 reviews
        last_10_reviews = data['Liked'].tail(10)  # Assuming last 10 reviews for analysis
        positive_count = len(last_10_reviews[last_10_reviews == 1])
        negative_count = len(last_10_reviews[last_10_reviews == 0])
        overall_sentiment_score = positive_count / (positive_count + negative_count)

        if overall_sentiment_score >= 0.5:
            recommendation_label.configure(text="Recommendation: You can consider visiting the restaurant.")
        else:
            recommendation_label.configure(text="Recommendation: It's not recommended to visit the restaurant.")

        # Display detailed review and sentiment
        review_text = data[' Review'].iloc[-1]  # Assuming we display the last entered review
        detailed_review_display.configure(text=f"Review: {review_text}\nPredicted Sentiment: {predicted_sentiment_human_readable}")

        # Calculate and display overall sentiment score
        overall_sentiment_label.configure(text=f"Overall Sentiment Score (Last 10 Reviews): {overall_sentiment_score:.2f}")

        # Update sentiment analysis visualization
        plt.figure(figsize=(6, 4))
        plt.bar(['Positive', 'Negative'], [positive_count, negative_count], color=['green', 'red'])
        plt.xlabel('Sentiment')
        plt.ylabel('Count')
        plt.title('Sentiment Analysis (Last 10 Reviews)')
        plt.tight_layout()
        plt.savefig('sentiment_analysis.png')

        # Display the visualization
        img = tk.PhotoImage(file='sentiment_analysis.png')
        sentiment_chart_display.configure(image=img)
        sentiment_chart_display.image = img

    else:
        sentiment_display.configure(text="Error: Unexpected sentiment prediction.")
        recommendation_label.configure(text="")
        detailed_review_display.configure(text="")
        overall_sentiment_label.configure(text="")
        sentiment_chart_display.configure(image="")

# Create a Tkinter window
root = tk.Tk()
root.title("Restaurant Review Sentiment Analysis")

# Create GUI elements
input_label = ttk.Label(root, text="Enter a Review:")
input_label.pack(pady=10)

input_entry = ttk.Entry(root, width=80)
input_entry.pack()

predict_button = ttk.Button(root, text="Predict", command=predict_sentiment)
predict_button.pack(pady=10)

sentiment_display = ttk.Label(root, text="", wraplength=600, justify='center', relief='solid', borderwidth=1, padding=10)
sentiment_display.pack(pady=20)

recommendation_label = ttk.Label(root, text="", font=("Arial", 12, "bold"))
recommendation_label.pack(pady=10)

detailed_review_display = ttk.Label(root, text="", wraplength=600, justify='center', relief='solid', borderwidth=1, padding=10)
detailed_review_display.pack(pady=20)

overall_sentiment_label = ttk.Label(root, text="")
overall_sentiment_label.pack(pady=10)

sentiment_chart_display = tk.Label(root)
sentiment_chart_display.pack()

# Start the Tkinter event loop
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from CSV file
data = pd.read_csv('res_review.csv')

# Initialize TF-IDF vectorizer
vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')
X = vectorizer.fit_transform(data[' Review'])  # Use ' Review' column for text vectorization
y = data['Liked']

# Train the SVM classifier
svm_classifier = SVC(kernel='linear')
svm_classifier.fit(X, y)

# Store entered reviews for batch analysis
entered_reviews = []

def add_review():
    review_text = input_entry.get()
    if review_text:
        entered_reviews.append(review_text)
        review_count_label.config(text=f"Reviews Entered: {len(entered_reviews)}")
        input_entry.delete(0, tk.END)

def analyze_reviews():
    if not entered_reviews:
        sentiment_display.configure(text="No reviews entered for analysis.")
        return

    # Transform entered reviews for analysis
    input_vectorized = vectorizer.transform(entered_reviews)
    predicted_sentiments = svm_classifier.predict(input_vectorized)
    sentiment_mapping = {0: 'Negative', 1: 'Positive'}  # Map integer predictions to sentiment labels

    # Calculate sentiment statistics
    positive_count = len(predicted_sentiments[predicted_sentiments == 1])
    negative_count = len(predicted_sentiments[predicted_sentiments == 0])
    overall_sentiment_score = positive_count / (positive_count + negative_count)

    # Update GUI with sentiment analysis results
    sentiment_display.configure(text=f"Positive Reviews: {positive_count}\nNegative Reviews: {negative_count}\nOverall Sentiment Score: {overall_sentiment_score:.2f}")

    # Clear entered reviews for next analysis
    entered_reviews.clear()
    review_count_label.config(text="Reviews Entered: 0")

# Create a Tkinter window
root = tk.Tk()
root.title("Batch Review Sentiment Analysis")

# Create GUI elements
input_label = ttk.Label(root, text="Enter a Review:")
input_label.pack(pady=10)

input_entry = ttk.Entry(root, width=80)
input_entry.pack()

add_button = ttk.Button(root, text="Add Review", command=add_review)
add_button.pack(pady=5)

review_count_label = ttk.Label(root, text="Reviews Entered: 0")
review_count_label.pack()

analyze_button = ttk.Button(root, text="Analyze Reviews", command=analyze_reviews)
analyze_button.pack(pady=10)

sentiment_display = ttk.Label(root, text="", wraplength=600, justify='center', relief='solid', borderwidth=1, padding=10)
sentiment_display.pack(pady=20)

# Start the Tkinter event loop
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from CSV file
data = pd.read_csv('res_review.csv')

# Initialize TF-IDF vectorizer
vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')
X = vectorizer.fit_transform(data[' Review'])  # Use ' Review' column for text vectorization
y = data['Liked']

# Train the SVM classifier
svm_classifier = SVC(kernel='linear')
svm_classifier.fit(X, y)

# Store entered reviews for batch analysis
entered_reviews = []

def add_review():
    review_text = input_entry.get()
    if review_text:
        entered_reviews.append(review_text)
        review_count_label.config(text=f"Reviews Entered: {len(entered_reviews)}")
        input_entry.delete(0, tk.END)

def analyze_reviews():
    if not entered_reviews:
        sentiment_display.configure(text="No reviews entered for analysis.")
        return

    # Transform entered reviews for analysis
    input_vectorized = vectorizer.transform(entered_reviews)
    predicted_sentiments = svm_classifier.predict(input_vectorized)
    sentiment_mapping = {0: 'Negative', 1: 'Positive'}  # Map integer predictions to sentiment labels

    # Calculate sentiment statistics
    positive_count = len(predicted_sentiments[predicted_sentiments == 1])
    negative_count = len(predicted_sentiments[predicted_sentiments == 0])
    overall_sentiment_score = positive_count / (positive_count + negative_count)

    # Update GUI with sentiment analysis results
    sentiment_display.configure(text=f"Positive Reviews: {positive_count}\nNegative Reviews: {negative_count}\nOverall Sentiment Score: {overall_sentiment_score:.2f}")

    # Plot sentiment analysis results
    plt.figure(figsize=(6, 4))
    plt.bar(['Positive', 'Negative'], [positive_count, negative_count])
    plt.xlabel('Sentiment')
    plt.ylabel('Count')
    plt.title('Sentiment Analysis Results')
    plt.show()

    # Provide recommendation based on sentiment score
    if overall_sentiment_score >= 0.5:
        recommendation_label.config(text="Recommendation: You may consider visiting this restaurant.")
    else:
        recommendation_label.config(text="Recommendation: It is advised to avoid visiting this restaurant.")

    # Clear entered reviews for next analysis
    entered_reviews.clear()
    review_count_label.config(text="Reviews Entered: 0")

# Create a Tkinter window
root = tk.Tk()
root.title("Batch Review Sentiment Analysis")

# Create GUI elements
input_label = ttk.Label(root, text="Enter a Review:")
input_label.pack(pady=10)

input_entry = ttk.Entry(root, width=80)
input_entry.pack()

add_button = ttk.Button(root, text="Add Review", command=add_review)
add_button.pack(pady=5)

review_count_label = ttk.Label(root, text="Reviews Entered: 0")
review_count_label.pack()

analyze_button = ttk.Button(root, text="Analyze Reviews", command=analyze_reviews)
analyze_button.pack(pady=10)

sentiment_display = ttk.Label(root, text="", wraplength=600, justify='center', relief='solid', borderwidth=1, padding=10)
sentiment_display.pack(pady=20)

recommendation_label = ttk.Label(root, text="", wraplength=600, justify='center', font=('Arial', 12, 'bold'))
recommendation_label.pack(pady=10)

# Start the Tkinter event loop
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from CSV file
data = pd.read_csv('res_review.csv')

# Initialize TF-IDF vectorizer
vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')
X = vectorizer.fit_transform(data[' Review'])  # Use ' Review' column for text vectorization
y = data['Liked']

# Train the SVM classifier
svm_classifier = SVC(kernel='linear')
svm_classifier.fit(X, y)

# Store entered reviews for batch analysis
entered_reviews = []

def add_review():
    review_text = input_entry.get()
    if review_text:
        entered_reviews.append(review_text)
        review_listbox.insert(tk.END, review_text)
        input_entry.delete(0, tk.END)

def analyze_reviews():
    if not entered_reviews:
        sentiment_display.configure(text="No reviews entered for analysis.")
        return

    # Transform entered reviews for analysis
    input_vectorized = vectorizer.transform(entered_reviews)
    predicted_sentiments = svm_classifier.predict(input_vectorized)
    sentiment_mapping = {0: 'Negative', 1: 'Positive'}  # Map integer predictions to sentiment labels

    # Calculate sentiment statistics
    positive_count = len(predicted_sentiments[predicted_sentiments == 1])
    negative_count = len(predicted_sentiments[predicted_sentiments == 0])
    overall_sentiment_score = positive_count / (positive_count + negative_count)

    # Update GUI with sentiment analysis results
    sentiment_display.configure(text=f"Positive Reviews: {positive_count}\nNegative Reviews: {negative_count}\nOverall Sentiment Score: {overall_sentiment_score:.2f}")

    # Plot sentiment analysis results
    plt.figure(figsize=(6, 4))
    plt.bar(['Positive', 'Negative'], [positive_count, negative_count])
    plt.xlabel('Sentiment')
    plt.ylabel('Count')
    plt.title('Sentiment Analysis Results')
    plt.show()

    # Provide recommendation based on sentiment score
    if overall_sentiment_score >= 0.5:
        recommendation_label.config(text="Recommendation: You may consider visiting this restaurant.")
    else:
        recommendation_label.config(text="Recommendation: It is advised to avoid visiting this restaurant.")

    # Clear entered reviews for next analysis
    entered_reviews.clear()
    review_listbox.delete(0, tk.END)

# Create a Tkinter window
root = tk.Tk()
root.title("Batch Review Sentiment Analysis")

# Create GUI elements
input_label = ttk.Label(root, text="Enter a Review:")
input_label.pack(pady=10)

input_entry = ttk.Entry(root, width=80)
input_entry.pack()

add_button = ttk.Button(root, text="Add Review", command=add_review)
add_button.pack(pady=5)

review_listbox = tk.Listbox(root, width=100, height=10)
review_listbox.pack()

analyze_button = ttk.Button(root, text="Analyze Reviews", command=analyze_reviews)
analyze_button.pack(pady=10)

sentiment_display = ttk.Label(root, text="", wraplength=600, justify='center', relief='solid', borderwidth=1, padding=10)
sentiment_display.pack(pady=20)

recommendation_label = ttk.Label(root, text="", wraplength=600, justify='center', font=('Arial', 12, 'bold'))
recommendation_label.pack(pady=10)

# Start the Tkinter event loop
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from CSV file
data = pd.read_csv('res_review.csv')

# Initialize TF-IDF vectorizer
vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')
X = vectorizer.fit_transform(data[' Review'])  # Use ' Review' column for text vectorization
y = data['Liked']

# Train the SVM classifier
svm_classifier = SVC(kernel='linear')
svm_classifier.fit(X, y)

# Store entered reviews for batch analysis
entered_reviews = []

def add_review():
    review_text = input_entry.get()
    if review_text:
        entered_reviews.append(review_text)
        update_review_listbox()
        input_entry.delete(0, tk.END)

def update_review_listbox():
    review_listbox.delete(0, tk.END)
    for i, review in enumerate(entered_reviews, 1):
        review_listbox.insert(tk.END, f"{i}. {review}")

def analyze_reviews():
    if not entered_reviews:
        sentiment_display.configure(text="No reviews entered for analysis.")
        return

    # Transform entered reviews for analysis
    input_vectorized = vectorizer.transform(entered_reviews)
    predicted_sentiments = svm_classifier.predict(input_vectorized)
    sentiment_mapping = {0: 'Negative', 1: 'Positive'}  # Map integer predictions to sentiment labels

    # Calculate sentiment statistics
    positive_count = len(predicted_sentiments[predicted_sentiments == 1])
    negative_count = len(predicted_sentiments[predicted_sentiments == 0])
    overall_sentiment_score = positive_count / (positive_count + negative_count)

    # Update GUI with sentiment analysis results
    sentiment_display.configure(text=f"Positive Reviews: {positive_count}\nNegative Reviews: {negative_count}\nOverall Sentiment Score: {overall_sentiment_score:.2f}")

    # Plot sentiment analysis results in a scatter plot
    plt.figure(figsize=(6, 4))
    plt.scatter(['Positive', 'Negative'], [positive_count, negative_count])
    plt.xlabel('Sentiment')
    plt.ylabel('Count')
    plt.title('Sentiment Analysis Results')
    plt.show()

    # Provide recommendation based on sentiment score
    if overall_sentiment_score >= 0.5:
        recommendation_label.config(text="Recommendation: You may consider visiting this restaurant.")
    else:
        recommendation_label.config(text="Recommendation: It is advised to avoid visiting this restaurant.")

    # Clear entered reviews for next analysis
    entered_reviews.clear()
    update_review_listbox()

# Create a Tkinter window
root = tk.Tk()
root.title("Batch Review Sentiment Analysis")

# Create GUI elements
input_label = ttk.Label(root, text="Enter a Review:")
input_label.pack(pady=10)

input_entry = ttk.Entry(root, width=80)
input_entry.pack()

add_button = ttk.Button(root, text="Add Review", command=add_review)
add_button.pack(pady=5)

review_listbox = tk.Listbox(root, width=100, height=10)
review_listbox.pack()

analyze_button = ttk.Button(root, text="Analyze Reviews", command=analyze_reviews)
analyze_button.pack(pady=10)

sentiment_display = ttk.Label(root, text="", wraplength=600, justify='center', relief='solid', borderwidth=1, padding=10)
sentiment_display.pack(pady=20)

recommendation_label = ttk.Label(root, text="", wraplength=600, justify='center', font=('Arial', 12, 'bold'))
recommendation_label.pack(pady=10)

# Start the Tkinter event loop
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from CSV file
data = pd.read_csv('res_review.csv')

# Initialize TF-IDF vectorizer
vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')
X = vectorizer.fit_transform(data[' Review'])  # Use ' Review' column for text vectorization
y = data['Liked']

# Train the SVM classifier
svm_classifier = SVC(kernel='linear')
svm_classifier.fit(X, y)

# Store entered reviews for batch analysis
entered_reviews = []

def add_review():
    review_text = input_entry.get()
    if review_text:
        entered_reviews.append(review_text)
        update_review_listbox()
        input_entry.delete(0, tk.END)

def update_review_listbox():
    review_listbox.delete(0, tk.END)
    for i, review in enumerate(entered_reviews, 1):
        review_listbox.insert(tk.END, f"{i}. {review}")

def analyze_reviews():
    if not entered_reviews:
        sentiment_display.configure(text="No reviews entered for analysis.", fg='red')
        return

    # Transform entered reviews for analysis
    input_vectorized = vectorizer.transform(entered_reviews)
    predicted_sentiments = svm_classifier.predict(input_vectorized)
    sentiment_mapping = {0: 'Negative', 1: 'Positive'}  # Map integer predictions to sentiment labels

    # Calculate sentiment statistics
    positive_count = len(predicted_sentiments[predicted_sentiments == 1])
    negative_count = len(predicted_sentiments[predicted_sentiments == 0])
    overall_sentiment_score = positive_count / (positive_count + negative_count)

    # Update GUI with sentiment analysis results
    sentiment_display.configure(text=f"Positive Reviews: {positive_count}\nNegative Reviews: {negative_count}\nOverall Sentiment Score: {overall_sentiment_score:.2f}", fg='green' if overall_sentiment_score >= 0.5 else 'red')

    # Plot sentiment analysis results in a bar graph
    plt.bar(['Positive', 'Negative'], [positive_count, negative_count], color=['green', 'red'])
    plt.xlabel('Sentiment')
    plt.ylabel('Count')
    plt.title('Sentiment Analysis Results')
    plt.show()

    # Provide recommendation based on sentiment score
    if overall_sentiment_score >= 0.5:
        recommendation_label.config(text="Recommendation: You may consider visiting this restaurant.", fg='green')
    else:
        recommendation_label.config(text="Recommendation: It is advised to avoid visiting this restaurant.", fg='red')

    # Clear entered reviews for next analysis
    entered_reviews.clear()
    update_review_listbox()

# Create a Tkinter window
root = tk.Tk()
root.title("Batch Review Sentiment Analysis")
root.configure(bg='lightblue')

# Create GUI elements
input_label = ttk.Label(root, text="Enter a Review:", font=('Arial', 12, 'bold'), background='lightblue')
input_label.pack(pady=10)

input_entry = ttk.Entry(root, width=80, font=('Arial', 10))
input_entry.pack()

add_button = ttk.Button(root, text="Add Review", command=add_review, style='Add.TButton')
add_button.pack(pady=5)

review_listbox = tk.Listbox(root, width=100, height=10, font=('Arial', 10), bg='white')
review_listbox.pack()

analyze_button = ttk.Button(root, text="Analyze Reviews", command=analyze_reviews, style='Analyze.TButton')
analyze_button.pack(pady=10)

sentiment_display = ttk.Label(root, text="", wraplength=600, justify='center', relief='solid', borderwidth=1, padding=10, font=('Arial', 12))
sentiment_display.pack(pady=20)

recommendation_label = ttk.Label(root, text="", wraplength=600, justify='center', font=('Arial', 12, 'bold'), background='lightblue')
recommendation_label.pack(pady=10)

# Define custom styles for buttons
style = ttk.Style()
style.configure('Add.TButton', font=('Arial', 10, 'bold'))
style.configure('Analyze.TButton', font=('Arial', 10, 'bold'))

# Start the Tkinter event loop
root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_7728\3612137555.py", line 51, in analyze_reviews
#     sentiment_display.configure(text=f"Positive Reviews: {positive_count}\nNegative Reviews: {negative_count}\nOverall Sentiment Score: {overall_sentiment_score:.2f}", fg='green' if overall_sentiment_score >= 0.5 else 'red')
#   File "C:\Users\HP\anaconda3\lib\tkinter\__init__.py", line 1675, in configure
#     return self._configure('configure', cnf, kw)
#   File "C:\Users\HP\anaconda3\lib\tkinter\__init__.py", line 1665, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: unknown option "-fg"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\lib\tkinter\__init__.py", line 1921, in __call__
# ...

# %%
import tkinter as tk
from tkinter import ttk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from CSV file
data = pd.read_csv('res_review.csv')

# Initialize TF-IDF vectorizer
vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')
X = vectorizer.fit_transform(data[' Review'])  # Use ' Review' column for text vectorization
y = data['Liked']

# Train the SVM classifier
svm_classifier = SVC(kernel='linear')
svm_classifier.fit(X, y)

# Store entered reviews for batch analysis
entered_reviews = []

def add_review():
    review_text = input_entry.get()
    if review_text:
        entered_reviews.append(review_text)
        review_listbox.insert(tk.END, review_text)
        input_entry.delete(0, tk.END)

def analyze_reviews():
    if not entered_reviews:
        sentiment_display.configure(text="No reviews entered for analysis.")
        return

    # Transform entered reviews for analysis
    input_vectorized = vectorizer.transform(entered_reviews)
    predicted_sentiments = svm_classifier.predict(input_vectorized)
    sentiment_mapping = {0: 'Negative', 1: 'Positive'}  # Map integer predictions to sentiment labels

    # Calculate sentiment statistics
    positive_count = len(predicted_sentiments[predicted_sentiments == 1])
    negative_count = len(predicted_sentiments[predicted_sentiments == 0])
    overall_sentiment_score = positive_count / (positive_count + negative_count)

    # Update GUI with sentiment analysis results
    sentiment_display.configure(text=f"Positive Reviews: {positive_count}\nNegative Reviews: {negative_count}\nOverall Sentiment Score: {overall_sentiment_score:.2f}")

    # Plot sentiment analysis results
    plt.figure(figsize=(6, 4))
    plt.bar(['Positive', 'Negative'], [positive_count, negative_count])
    plt.xlabel('Sentiment')
    plt.ylabel('Count')
    plt.title('Sentiment Analysis Results')
    plt.show()

    # Provide recommendation based on sentiment score
    if overall_sentiment_score >= 0.5:
        recommendation_label.config(text="Recommendation: You may consider visiting this restaurant.")
    else:
        recommendation_label.config(text="Recommendation: It is advised to avoid visiting this restaurant.")

    # Clear entered reviews for next analysis
    entered_reviews.clear()
    review_listbox.delete(0, tk.END)

# Create a Tkinter window
root = tk.Tk()
root.title("Batch Review Sentiment Analysis")

# Create GUI elements
input_label = ttk.Label(root, text="Enter a Review:")
input_label.pack(pady=10)

input_entry = ttk.Entry(root, width=80)
input_entry.pack()

add_button = ttk.Button(root, text="Add Review", command=add_review)
add_button.pack(pady=5)

review_listbox = tk.Listbox(root, width=100, height=10)
review_listbox.pack()

analyze_button = ttk.Button(root, text="Analyze Reviews", command=analyze_reviews)
analyze_button.pack(pady=10)

sentiment_display = ttk.Label(root, text="", wraplength=600, justify='center', relief='solid', borderwidth=1, padding=10)
sentiment_display.pack(pady=20)

recommendation_label = ttk.Label(root, text="", wraplength=600, justify='center', font=('Arial', 12, 'bold'))
recommendation_label.pack(pady=10)

# Start the Tkinter event loop
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from CSV file
data = pd.read_csv('res_review.csv')

# Initialize TF-IDF vectorizer
vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')
X = vectorizer.fit_transform(data[' Review'])  # Use ' Review' column for text vectorization
y = data['Liked']

# Train the SVM classifier
svm_classifier = SVC(kernel='linear')
svm_classifier.fit(X, y)

# Store entered reviews for batch analysis
entered_reviews = []

def add_review():
    review_text = input_entry.get()
    if review_text:
        entered_reviews.append(review_text)
        update_review_listbox()
        input_entry.delete(0, tk.END)

def update_review_listbox():
    review_listbox.delete(0, tk.END)
    for i, review in enumerate(entered_reviews, 1):
        review_listbox.insert(tk.END, f"{i}. {review}")

def analyze_reviews():
    if not entered_reviews:
        sentiment_display.configure(text="No reviews entered for analysis.")
        return

    # Transform entered reviews for analysis
    input_vectorized = vectorizer.transform(entered_reviews)
    predicted_sentiments = svm_classifier.predict(input_vectorized)
    sentiment_mapping = {0: 'Negative', 1: 'Positive'}  # Map integer predictions to sentiment labels

    # Calculate sentiment statistics
    positive_count = len(predicted_sentiments[predicted_sentiments == 1])
    negative_count = len(predicted_sentiments[predicted_sentiments == 0])
    overall_sentiment_score = positive_count / (positive_count + negative_count)

    # Update GUI with sentiment analysis results
    sentiment_display.configure(text=f"Positive Reviews: {positive_count}\nNegative Reviews: {negative_count}\nOverall Sentiment Score: {overall_sentiment_score:.2f}", foreground='green' if overall_sentiment_score >= 0.5 else 'red')

    # Plot sentiment analysis results in a bar graph
    plt.figure(figsize=(6, 4))
    plt.bar(['Positive', 'Negative'], [positive_count, negative_count], color=['green', 'red'])
    plt.xlabel('Sentiment')
    plt.ylabel('Count')
    plt.title('Sentiment Analysis Results')
    plt.show()

    # Provide recommendation based on sentiment score
    if overall_sentiment_score >= 0.5:
        recommendation_label.config(text="Recommendation: You may consider visiting this restaurant.", foreground='green')
    else:
        recommendation_label.config(text="Recommendation: It is advised to avoid visiting this restaurant.", foreground='red')

    # Clear entered reviews for next analysis
    entered_reviews.clear()
    update_review_listbox()

# Create a Tkinter window
root = tk.Tk()
root.title("Batch Review Sentiment Analysis")

# Create GUI elements with colorful styles
input_label = ttk.Label(root, text="Enter a Review:", foreground='blue')
input_label.pack(pady=10)

input_entry = ttk.Entry(root, width=80)
input_entry.pack()

add_button = ttk.Button(root, text="Add Review", command=add_review, style='Add.TButton')
add_button.pack(pady=5)

review_listbox = tk.Listbox(root, width=100, height=10)
review_listbox.pack()

analyze_button = ttk.Button(root, text="Analyze Reviews", command=analyze_reviews, style='Analyze.TButton')
analyze_button.pack(pady=10)

sentiment_display = ttk.Label(root, text="", wraplength=600, justify='center', relief='solid', borderwidth=1, padding=10)
sentiment_display.pack(pady=20)

recommendation_label = ttk.Label(root, text="", wraplength=600, justify='center', font=('Arial', 12, 'bold'))
recommendation_label.pack(pady=10)

# Define custom styles for buttons
style = ttk.Style()
style.configure('Add.TButton', font=('Arial', 10, 'bold'), foreground='blue')
style.configure('Analyze.TButton', font=('Arial', 10, 'bold'), foreground='green')

# Start the Tkinter event loop
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from CSV file
data = pd.read_csv('res_review.csv')

# Initialize TF-IDF vectorizer
vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')
X = vectorizer.fit_transform(data[' Review'])  # Use ' Review' column for text vectorization
y = data['Liked']

# Train the SVM classifier
svm_classifier = SVC(kernel='linear')
svm_classifier.fit(X, y)

# Store entered reviews for batch analysis
entered_reviews = []

def add_review():
    review_text = input_entry.get()
    if review_text:
        entered_reviews.append(review_text)
        update_review_listbox()
        input_entry.delete(0, tk.END)

def update_review_listbox():
    review_listbox.delete(0, tk.END)
    for i, review in enumerate(entered_reviews, 1):
        review_listbox.insert(tk.END, f"{i}. {review}")

def analyze_reviews():
    if not entered_reviews:
        sentiment_display.configure(text="No reviews entered for analysis.")
        return

    # Transform entered reviews for analysis
    input_vectorized = vectorizer.transform(entered_reviews)
    predicted_sentiments = svm_classifier.predict(input_vectorized)
    sentiment_mapping = {0: 'Negative', 1: 'Positive'}  # Map integer predictions to sentiment labels

    # Calculate sentiment statistics
    positive_count = len(predicted_sentiments[predicted_sentiments == 1])
    negative_count = len(predicted_sentiments[predicted_sentiments == 0])
    overall_sentiment_score = positive_count / (positive_count + negative_count)

    # Update GUI with sentiment analysis results
    sentiment_display.configure(text=f"Positive Reviews: {positive_count}\nNegative Reviews: {negative_count}\nOverall Sentiment Score: {overall_sentiment_score:.2f}", foreground='green' if overall_sentiment_score >= 0.5 else 'red')

    # Plot sentiment analysis results in a bar graph
    plt.figure(figsize=(6, 4))
    plt.bar(['Positive', 'Negative'], [positive_count, negative_count], color=['green', 'red'])
    plt.xlabel('Sentiment')
    plt.ylabel('Count')
    plt.title('Sentiment Analysis Results')
    plt.show()

    # Provide recommendation based on sentiment score
    if overall_sentiment_score >= 0.5:
        recommendation_label.config(text="Recommendation: You may consider visiting this restaurant.", foreground='green')
    else:
        recommendation_label.config(text="Recommendation: It is advised to avoid visiting this restaurant.", foreground='red')

    # Clear entered reviews for next analysis
    entered_reviews.clear()
    update_review_listbox()

# Create a Tkinter window
root = tk.Tk()
root.title("Batch Review Sentiment Analysis")

# Set light blue background color
root.configure(bg='lightblue')

# Create GUI elements with colorful styles
input_label = ttk.Label(root, text="Enter a Review:", foreground='blue', background='lightblue')
input_label.pack(pady=10)

input_entry = ttk.Entry(root, width=80)
input_entry.pack()

style = ttk.Style()
style.configure('TButton', foreground='blue', background='lightblue')

add_button = ttk.Button(root, text="Add Review", command=add_review, style='TButton')
add_button.pack(pady=5)

review_listbox = tk.Listbox(root, width=100, height=10, bg='lightblue')
review_listbox.pack()

analyze_button = ttk.Button(root, text="Analyze Reviews", command=analyze_reviews, style='TButton')
analyze_button.pack(pady=10)

sentiment_display = ttk.Label(root, text="", wraplength=600, justify='center', relief='solid', borderwidth=1, padding=10, background='lightblue')
sentiment_display.pack(pady=20)

recommendation_label = ttk.Label(root, text="", wraplength=600, justify='center', font=('Arial', 12, 'bold'), background='lightblue')
recommendation_label.pack(pady=10)

# Start the Tkinter event loop
root.mainloop()
