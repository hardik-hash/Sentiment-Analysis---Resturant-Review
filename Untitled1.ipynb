# %%
import pandas as pd

# %%
s = pd.read_csv('sentiment_data.csv')

# %%
m=pd.read_csv('movie_review.csv')

# %%
print(s)
# Out:
#        fold_id cv_tag  html_id  sent_id  \
# 0            0  cv000    29590        0
# 1            0  cv000    29590        1
# 2            0  cv000    29590        2
# 3            0  cv000    29590        3
# 4            0  cv000    29590        4
# ...        ...    ...      ...      ...
# 64715        9  cv999    14636       20
# 64716        9  cv999    14636       21
# 64717        9  cv999    14636       22
# 64718        9  cv999    14636       23
# 64719        9  cv999    14636       24
#
#                                                     text  tag sentiment
# 0      films adapted from comic books have had plenty...  pos  Negative
# 1      for starters , it was created by alan moore ( ...  pos  Positive
# 2      to say moore and campbell thoroughly researche...  pos  Positive
# 3      the book ( or " graphic novel , " if you will ...  pos  Positive
# 4      in other words , don't dismiss this film becau...  pos   Neutral
# ...                                                  ...  ...       ...
# 64715  that lack of inspiration can be traced back to...  neg  Negative
# 64716  like too many of the skits on the current inca...  neg  Positive
# 64717  after watching one of the " roxbury " skits on...  neg  Positive
# 64718   bump unsuspecting women , and . . . that's all .  neg   Neutral
# 64719  after watching _a_night_at_the_roxbury_ , you'...  neg   Neutral
#
# [64720 rows x 7 columns]

# %%
import tkinter as tk
from tkinter import ttk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
import pandas as pd

# Load the sentiment analysis dataset from a CSV file
data = pd.read_csv('your_dataset.csv')  # Replace 'your_dataset.csv' with your actual CSV file

# Preprocess text data and extract features using TF-IDF vectorization
vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')
X = vectorizer.fit_transform(data['text'])
y = data['sentiment']

# Train a Support Vector Machine (SVM) classifier
svm_classifier = SVC(kernel='linear')
svm_classifier.fit(X, y)

def predict_sentiment():
    input_text = input_entry.get()
    input_vectorized = vectorizer.transform([input_text])
    predicted_sentiment = svm_classifier.predict(input_vectorized)
    sentiment_mapping = {0: 'negative', 1: 'positive'}  # Use integers as keys
    predicted_sentiment_human_readable = sentiment_mapping[predicted_sentiment[0]]
    sentiment_label.config(text=f"Predicted Sentiment: {predicted_sentiment_human_readable}")

# Create a Tkinter window
root = tk.Tk()
root.title("Sentiment Analysis")

# Create GUI elements
input_label = ttk.Label(root, text="Enter a sentence:")
input_label.pack(pady=10)

input_entry = ttk.Entry(root, width=50)
input_entry.pack()

predict_button = ttk.Button(root, text="Predict", command=predict_sentiment)
predict_button.pack(pady=10)

sentiment_label = ttk.Label(root, text="")
sentiment_label.pack()

# Start the Tkinter event loop
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
import speech_recognition as sr
from nltk.sentiment import SentimentIntensityAnalyzer
import threading
import time
import math

# Download NLTK resources if not already downloaded
import nltk

# Initialize the Sentiment Intensity Analyzer
sia = SentimentIntensityAnalyzer()

def analyze_voice_sentiment(audio):
    """Analyze the sentiment of speech input and return a sentiment label."""
    text = recognizer.recognize_google(audio)
    scores = sia.polarity_scores(text)
    if scores['compound'] >= 0.05:
        return 'Positive'
    elif scores['compound'] <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

def start_listening():
    """Start listening for speech input."""
    global listening
    listening = True
    status_label.config(text="Listening...")
    # Start a thread for processing audio
    threading.Thread(target=process_audio).start()

def stop_listening():
    """Stop listening for speech input."""
    global listening
    listening = False
    status_label.config(text="Not Listening")

def process_audio():
    """Process the recorded audio for sentiment analysis."""
    while listening:
        with sr.Microphone() as source:
            audio = recognizer.listen(source)
        try:
            label = analyze_voice_sentiment(audio)
            sentiment_label.config(text=f"Sentiment: {label}")
        except sr.UnknownValueError:
            sentiment_label.config(text="Could not understand audio")
        except sr.RequestError as e:
            sentiment_label.config(text=f"Error: {e}")

def draw_wave(canvas, amplitude, period, width, height):
    """Draw a wave-like pattern on the canvas."""
    canvas.delete("all")
    points = []
    for x in range(0, width, 5):
        y = amplitude * math.sin(2 * math.pi * x / period) + height / 2
        points.append((x, y))
    canvas.create_line(points, fill="blue", smooth=True)

# Initialize Tkinter window
root = tk.Tk()
root.title("Speech Sentiment Analysis")
root.geometry("400x400")

# Create GUI elements
status_label = ttk.Label(root, text="Not Listening", font=("Arial", 12))
status_label.pack(pady=10)

start_button = ttk.Button(root, text="Start Listening", command=start_listening)
start_button.pack()

stop_button = ttk.Button(root, text="Stop Listening", command=stop_listening)
stop_button.pack()

canvas = tk.Canvas(root, width=400, height=200)
canvas.pack()

sentiment_label = ttk.Label(root, text="Sentiment: ", font=("Arial", 12))
sentiment_label.pack(pady=10)

# Initialize SpeechRecognizer
recognizer = sr.Recognizer()

# Start processing audio asynchronously
listening = False

# Start the wave animation
amplitude = 50
period = 50
width = 400
height = 200

while True:
    if listening:
        draw_wave(canvas, amplitude, period, width, height)
        amplitude += 1  # Change the amplitude for animation effect
        root.update()
    time.sleep(0.05)

# Start the Tkinter event loop
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
import speech_recognition as sr
from nltk.sentiment import SentimentIntensityAnalyzer
import threading
import time
import math

# Download NLTK resources if not already downloaded
import nltk

# %%
sia = SentimentIntensityAnalyzer()

def analyze_voice_sentiment(audio):
    """Analyze the sentiment of speech input and return a sentiment label."""
    text = recognizer.recognize_google(audio)
    scores = sia.polarity_scores(text)
    if scores['compound'] >= 0.05:
        return 'Positive'
    elif scores['compound'] <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

def start_listening():
    """Start listening for speech input."""
    global listening
    listening = True
    status_label.config(text="Listening...")
    # Start a thread for processing audio
    threading.Thread(target=process_audio).start()

def stop_listening():
    """Stop listening for speech input."""
    global listening
    listening = False
    status_label.config(text="Not Listening")

def process_audio():
    """Process the recorded audio for sentiment analysis."""
    while listening:
        with sr.Microphone() as source:
            audio = recognizer.listen(source)
        try:
            label = analyze_voice_sentiment(audio)
            sentiment_label.config(text=f"Sentiment: {label}")
        except sr.UnknownValueError:
            sentiment_label.config(text="Could not understand audio")
        except sr.RequestError as e:
            sentiment_label.config(text=f"Error: {e}")

def draw_wave(canvas, amplitude, period, width, height):
    """Draw a wave-like pattern on the canvas."""
    canvas.delete("all")
    points = []
    for x in range(0, width, 5):
        y = amplitude * math.sin(2 * math.pi * x / period) + height / 2
        points.append((x, y))
    canvas.create_line(points, fill="blue", smooth=True)

# %%
root = tk.Tk()
root.title("Speech Sentiment Analysis")
root.geometry("400x400")

# Create GUI elements
status_label = ttk.Label(root, text="Not Listening", font=("Arial", 12))
status_label.pack(pady=10)

start_button = ttk.Button(root, text="Start Listening", command=start_listening)
start_button.pack()

stop_button = ttk.Button(root, text="Stop Listening", command=stop_listening)
stop_button.pack()

canvas = tk.Canvas(root, width=400, height=200)
canvas.pack()

sentiment_label = ttk.Label(root, text="Sentiment: ", font=("Arial", 12))
sentiment_label.pack(pady=10)

# %%
# Initialize SpeechRecognizer
recognizer = sr.Recognizer()

# Start processing audio asynchronously
listening = False

# Start the wave animation
amplitude = 50
period = 50
width = 400
height = 200

while True:
    if listening:
        draw_wave(canvas, amplitude, period, width, height)
        amplitude += 1  # Change the amplitude for animation effect
        root.update()
    time.sleep(0.05)

# Start the Tkinter event loop
root.mainloop()
